# %%
import pandas as pd

file = "Resources/gnv-b"
gun_violence_b = pd.read_csv(file)
gun_violence_b.head()
# Out:
#                                                                                                                                                                                                    Unnamed: 0  \
# 616180 2016-07-29 Delaware   Dover          Stevenson Drive                   0 0 http://www.gunviolencearchive.org/incident/616180 http://www.wboc.com/story/32573555/fight-betwee... False 1.0   0::Unknown
# 616182 2016-07-29 Nevada     Sparks         1690 Merchant St                  1 0 http://www.gunviolencearchive.org/incident/616182 http://www.ktvn.com/story/32572611/sparks-polic... False 2.0          NaN
# 616988 2016-07-29 California San Bernardino 11th Street and Acacia Avenue     0 1 http://www.gunviolencearchive.org/incident/616988 http://www.sbsun.com/general-news/20160729/man-... False 31.0  0::Unknown
# ...

# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Load CSV
file_to_load = 'Resources/nst-est2018-alldata.csv'
pop_data = pd.read_csv(file_to_load)
pop_data.head(10)
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  CENSUS2010POP  \
# 0      10      0        0      0     United States      308745538
# 1      20      1        0      0  Northeast Region       55317240
# 2      20      2        0      0    Midwest Region       66927001
# 3      20      3        0      0      South Region      114555744
# 4      20      4        0      0       West Region       71945553
# 5      40      3        6      1           Alabama        4779736
# 6      40      4        9      2            Alaska         710231
# 7      40      4        8      4           Arizona        6392017
# 8      40      3        7      5          Arkansas        2915918
# 9      40      4        9      6        California       37253956
#
#    ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0          308758105        309326085        311580009        313874218
# 1           55318430         55380645         55600532         55776729
# ...

# %%
# Clean 2017 ACS Population Estimates by State 
pop_clean = pop_data[['NAME','POPESTIMATE2017']]
pop_2017 = pop_clean.drop(axis=0, labels=range(5))
pop_2017.reset_index(drop=True, inplace=True)
pop_2017.head(51)
# Out:
#                     NAME  POPESTIMATE2017
# 0                Alabama          4875120
# 1                 Alaska           739786
# 2                Arizona          7048876
# 3               Arkansas          3002997
# 4             California         39399349
# 5               Colorado          5615902
# 6            Connecticut          3573880
# 7               Delaware           957078
# 8   District of Columbia           695691
# 9                Florida         20976812
# 10               Georgia         10413055
# 11                Hawaii          1424203
# 12                 Idaho          1718904
# 13              Illinois         12786196
# 14               Indiana          6660082
# 15                  Iowa          3143637
# 16                Kansas          2910689
# 17              Kentucky          4453874
# 18             Louisiana          4670818
# 19                 Maine          1335063
# 20              Maryland          6024891
# ...
